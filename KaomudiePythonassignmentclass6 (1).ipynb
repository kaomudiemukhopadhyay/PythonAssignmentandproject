# %%
1- Create a Pandas Data frame from the given data and create a new column “Voter” based on
voter age, i.e., if age >18 then voter column should be “Yes” otherwise if age <18 then voter
column should be “No”

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

raw_Data = {'Voter_name': ['Geek1', 'Geek2', 'Geek3', 'Geek4', 'Geek5', 'Geek6', 'Geek7', 'Geek8'],
            'Voter_age': [15, 23, 25, 9, 67, 54, 42, np.NaN]}
df = pd.DataFrame(raw_Data)

# Create a new column "Voter" based on voter age
df['Voter'] = np.where(df['Voter_age'] > 18, 'Yes', 'No')

print(df)
# Out:
#   Voter_name  Voter_age Voter
# 0      Geek1       15.0    No
# 1      Geek2       23.0   Yes
# 2      Geek3       25.0   Yes
# 3      Geek4        9.0    No
# 4      Geek5       67.0   Yes
# 5      Geek6       54.0   Yes
# 6      Geek7       42.0   Yes
# 7      Geek8        NaN    No

# %%
2 – Create a Pandas Data frame from the given data and collapse First and Last column into one
column as Full Name, so the output contains Full Name and Age, then convert column age to
index
raw_Data = {'First': ['Manan ', 'Raghav ', 'Sunny '],
'Last': ['Goel', 'Sharma', 'Chawla'],
'Age' : [12, 24, 56]}

# %%
import pandas as pd

raw_Data = {'First': ['Manan', 'Raghav', 'Sunny'],
            'Last': ['Goel', 'Sharma', 'Chawla'],
            'Age': [12, 24, 56]}

df = pd.DataFrame(raw_Data)

# Combine First and Last columns into Full Name
df['Full Name'] = df['First'] + ' ' + df['Last']

# Set Age as index
df.set_index('Age', inplace=True)

print(df)
# Out:
#       First    Last      Full Name
# Age
# 12    Manan    Goel     Manan Goel
# 24   Raghav  Sharma  Raghav Sharma
# 56    Sunny  Chawla   Sunny Chawla

# %%
3- Create a Pandas Data frame from the given data -
raw_Data = {'Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
'Product':['Umbrella', 'Matress', 'Badminton','Shuttle'],
'Price':[1250, 1450, 1550, 400],
'Expense': [ 21525220.653, 31125840.875, 23135428.768, 56245263.942]}
a- Add Index as Item1, Item2, Item3, Item4
b- Find the index labels of all items whose ‘Price’ is greater than 1000.
c- Replace products using Map() with respective codes- Umbrella : ‘U’, Matress : 'M', Badminton
: 'B', Shuttle: 'S'
d- Round off the Expense column values to two decimal places.
e- Create a new column called ‘Discounted_Price’ after applying a 10% discount on the existing
‘price’ column.(try using lambda function)
f- Convert the column type of “Date” to datetime format
Grow Data Skil s
g- Create a column rank which ranks the products based on the price (one with the highest price
will be rank 1).

# %%
import pandas as pd

raw_Data = {'Date': ['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
            'Product': ['Umbrella', 'Matress', 'Badminton', 'Shuttle'],
            'Price': [1250, 1450, 1550, 400],
            'Expense': [21525220.653, 31125840.875, 23135428.768, 56245263.942]}

df = pd.DataFrame(raw_Data)

# Task a: Add Index as Item1, Item2, Item3, Item4
df.index = ['Item1', 'Item2', 'Item3', 'Item4']

# Task b: Find index labels with Price > 1000
indexes_with_price_gt_1000 = df[df['Price'] > 1000].index.tolist()

# Task c: Replace products using Map()
product_map = {'Umbrella': 'U', 'Matress': 'M', 'Badminton': 'B', 'Shuttle': 'S'}
df['Product'] = df['Product'].map(product_map)

# Task d: Round off Expense column to two decimal places
df['Expense'] = df['Expense'].round(2)

# Task e: Create 'Discounted_Price' column with 10% discount
df['Discounted_Price'] = df['Price'] * 0.9

# Task f: Convert 'Date' column to datetime format with dayfirst=True
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# Task g: Create 'Rank' column based on price
df['Rank'] = df['Price'].rank(ascending=False).astype(int)

print(df)
print("Index labels with Price > 1000:", indexes_with_price_gt_1000)
# Out:
#             Date Product  Price      Expense  Discounted_Price  Rank
# Item1 2011-02-10       U   1250  21525220.65            1125.0     3
# Item2 2011-02-11       M   1450  31125840.88            1305.0     2
# Item3 2011-02-12       B   1550  23135428.77            1395.0     1
# Item4 2011-02-13       S    400  56245263.94             360.0     4
# Index labels with Price > 1000: ['Item1', 'Item2', 'Item3']

# %% [markdown]
# ###### Data Analysis #####
# Assignment: Exploring NBA Player Data
# Download the nba.csv file containing NBA player data Complete the following tasks using
# Python, Pandas, and data visualization libraries:
# 1. Load Data:
# ● Load the nba.csv data into a Pandas DataFrame.
# ● Display basic information about the DataFrame.
# 2. Data Cleaning:
# ● Handle missing values by either removing or imputing them.
# ● Remove duplicate rows.
# 3. Data Transformation:
# ● Create a new column 'BMI' (Body Mass Index) using the formula: BMI = (weight in
# pounds / (height in inches)^2) * 703.(Assuming a fixed height value of 70 inches (5 feet
# 10 inches)
# 4. Exploratory Data Analysis (EDA):
# ● Display summary statistics of the 'age', 'weight', and 'salary' columns.
# ● Calculate the average age, weight, and salary of players in each 'position' category.
# 5. Data Visualization:
# ● Create a histogram of player ages.
# ● Create a boxplot of player salaries for each 'position'.
# ● Plot a scatter plot of 'age' vs. 'salary' with a different color for each 'position'.
# 6. Top Players:
# ● Display the top 10 players with the highest salaries.
# 7. College Analysis:
# ● Determine the top 5 colleges with the most represented players.
# 8. Position Distribution:
# Grow Data Skil s
# ● Plot a pie chart to show the distribution of players across different 'positions'.
# 9. Team Analysis:
# ● Display the average salary of players for each 'team'.
# ● Plot a bar chart to visualize the average salary of players for each 'team'.
# 10. Extras
# ● Get the index at which the minimum weight value is present.
# ● Sort values based on name in alphabetical order for the rows (the original Dataframe
# sorting should not change)
# ● Create a series from given dataframe on “name” column and display top and last 10
#
# Guidelines:
# 1. Write Python code to complete each task.
# 2. Provide comments explaining your code.
# 3. Use meaningful variable names.
# 4. Include necessary library imports.
# 5. Present your findings in a clear and organized manner.
# 6. Feel free to use additional code cells for each task

# %%
1. Load Data:
● Load the nba.csv data into a Pandas DataFrame.
● Display basic information about the DataFrame.

# %%
import pandas as pd
# Load the data into a Pandas DataFrame
df = pd.read_csv('nba.csv')
# Display basic information about the DataFrame
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Weight    457 non-null    int64
#  6   College   373 non-null    object
#  7   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 28.7+ KB
# None
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
2. Data Cleaning:
● Handle missing values by either removing or imputing them.
● Remove duplicate rows

# %%
import pandas as pd

# Load the data into a Pandas DataFrame
df = pd.read_csv('nba.csv')

# Handle missing values by dropping rows with missing values
df.dropna(inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Display basic information about the cleaned DataFrame
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    int64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    int64
#  5   Weight    364 non-null    int64
#  6   College   364 non-null    object
#  7   Salary    364 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 25.6+ KB
# None
#             Name            Team  Number Position  Age  Weight        College  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180          Texas
# 1    Jae Crowder  Boston Celtics      99       SF   25     235      Marquette
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185  Georgia State
# 6  Jordan Mickey  Boston Celtics      55       PF   21     235            LSU
# 7   Kelly Olynyk  Boston Celtics      41        C   25     238        Gonzaga
#
#       Salary
# 0  7730337.0
# 1  6796117.0
# 3  1148640.0
# 6  1170960.0
# 7  2165160.0

# %%
3. Data Transformation:
● Create a new column 'BMI' (Body Mass Index) using the formula: BMI = (weight in
pounds / (height in inches)^2) * 703.(Assuming a fixed height value of 70 inches (5 feet
10 inches)

# %%
import pandas as pd

# Load the data into a Pandas DataFrame
df = pd.read_csv('nba.csv')

# Assuming a fixed height value of 70 inches (5 feet 10 inches)
fixed_height = 70

# Create 'BMI' column
df['BMI'] = (df['Weight'] / (fixed_height ** 2)) * 703

# Display the DataFrame with the new 'BMI' column
print(df.head())
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
#
#              College     Salary        BMI
# 0              Texas  7730337.0  25.824490
# 1          Marquette  6796117.0  33.715306
# 2  Boston University        NaN  29.411224
# 3      Georgia State  1148640.0  26.541837
# 4                NaN  5000000.0  33.141429

# %%
4. Exploratory Data Analysis (EDA):
● Display summary statistics of the 'age', 'weight', and 'salary' columns.
● Calculate the average age, weight, and salary of players in each 'position' category

# %%
import pandas as pd

# Load the data into a Pandas DataFrame
df = pd.read_csv('nba.csv')

# Display summary statistics of 'age', 'weight', and 'salary' columns
summary_stats = df[['Age', 'Weight', 'Salary']].describe()
print("Summary Statistics:")
print(summary_stats)

# Calculate the average age, weight, and salary by 'position' category
avg_by_position = df.groupby('Position')[['Age', 'Weight', 'Salary']].mean()
print("\nAverage Age, Weight, and Salary by Position:")
print(avg_by_position)
# Out:
# Summary Statistics:
#               Age      Weight        Salary
# count  457.000000  457.000000  4.460000e+02
# mean    26.938731  221.522976  4.842684e+06
# std      4.404016   26.368343  5.229238e+06
# min     19.000000  161.000000  3.088800e+04
# 25%     24.000000  200.000000  1.044792e+06
# 50%     26.000000  220.000000  2.839073e+06
# 75%     30.000000  240.000000  6.500000e+06
# max     40.000000  307.000000  2.500000e+07
#
# Average Age, Weight, and Salary by Position:
#                 Age      Weight        Salary
# Position
# C         27.371795  254.205128  5.967052e+06
# PF        27.160000  240.430000  4.562483e+06
# PG        26.847826  189.478261  5.077829e+06
# SF        26.858824  221.776471  4.857393e+06
# SG        26.539216  206.686275  4.009861e+06

# %%
5. 5. Data Visualization:
● Create a histogram of player ages.
● Create a boxplot of player salaries for each 'position'.
● Plot a scatter plot of 'age' vs. 'salary' with a different color for each 'position'

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Histogram of player ages
plt.hist(df['Age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Player Ages')
plt.show()

# %% [markdown]
# # Box plot of player salaries by position ● Create a boxplot of player salaries for each 'position'.

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Box plot of player salaries by position
df.boxplot(column='Salary', by='Position')
plt.ylabel('Salary')
plt.title('Box Plot of Player Salaries by Position')
plt.suptitle('')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Plot a scatter plot of 'age' vs. 'salary' with a different color for each 'position

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Define colors based on positions
colors = {'PG': 'red', 'SG': 'blue', 'SF': 'green', 'PF': 'purple', 'C': 'orange'}

# Scatter plot of 'age' vs. 'salary'
plt.scatter(df['Age'], df['Salary'], c=df['Position'].map(colors), alpha=0.5)

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs. Salary by Position')

# Add legend for positions
plt.legend(colors)

# Display the plot
plt.show()

# %%
6. Top Players:
● Display the top 10 players with the highest salaries.

# %%
# Display the top 10 players with the highest salaries
top_players = df.nlargest(10, 'Salary')
print(top_players)
# Out:
#                 Name                   Team  Number Position  Age  Weight  \
# 109      Kobe Bryant     Los Angeles Lakers      24       SF   37     212
# 169     LeBron James    Cleveland Cavaliers      23       SF   31     250
# 33   Carmelo Anthony        New York Knicks       7       SF   32     240
# 251    Dwight Howard        Houston Rockets      12        C   30     265
# 339       Chris Bosh             Miami Heat       1       PF   32     235
# 100       Chris Paul   Los Angeles Clippers       3       PG   31     175
# 414     Kevin Durant  Oklahoma City Thunder      35       SF   27     240
# 164     Derrick Rose          Chicago Bulls       1       PG   27     190
# 349      Dwyane Wade             Miami Heat       3       SG   34     220
# 23       Brook Lopez          Brooklyn Nets      11        C   28     275
#
#           College      Salary
# 109           NaN  25000000.0
# 169           NaN  22970500.0
# 33       Syracuse  22875000.0
# 251           NaN  22359364.0
# 339  Georgia Tech  22192730.0
# 100   Wake Forest  21468695.0
# 414         Texas  20158622.0
# 164       Memphis  20093064.0
# 349     Marquette  20000000.0
# 23       Stanford  19689000.0

# %%
7. College Analysis:
● Determine the top 5 colleges with the most represented players.

# %%
# Determine the top 5 colleges with the most represented players
top_colleges = df['College'].value_counts().nlargest(5)
print(top_colleges)
# Out:
# College
# Kentucky          22
# Duke              20
# Kansas            18
# North Carolina    16
# UCLA              15
# Name: count, dtype: int64

# %%
8. Position Distribution:

● Plot a pie chart to show the distribution of players across different 'positions'.

# %%
import matplotlib.pyplot as plt

# Calculate the counts of players in each position
position_counts = df['Position'].value_counts()

# Create a pie chart
plt.pie(position_counts, labels=position_counts.index, autopct='%1.1f%%', startangle=140)

# Set the title and ensure equal aspect ratio
plt.title('Position Distribution of Players')
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
9. Team Analysis:
● Display the average salary of players for each 'team'.
● Plot a bar chart to visualize the average salary of players for each 'team'.

# %%
import matplotlib.pyplot as plt

# Calculate the average salary of players for each team
avg_salary_by_team = df.groupby('Team')['Salary'].mean()
print(avg_salary_by_team)

# Create a bar chart
plt.figure(figsize=(10, 6))
avg_salary_by_team.plot(kind='bar')
plt.xlabel('Team')
plt.ylabel('Average Salary')
plt.title('Average Salary of Players by Team')
plt.xticks(rotation=45)
plt.show()
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# Portland Trail Blazers    3.220121e+06
# Sacramento Kings          4.778911e+06
# San Antonio Spurs         5.629516e+06
# Toronto Raptors           4.741174e+06
# Utah Jazz                 4.204006e+06
# Washington Wizards        5.088576e+06
# Name: Salary, dtype: float64

# %%
10. Extras
● Get the index at which the minimum weight value is present.
● Sort values based on name in alphabetical order for the rows (the original Dataframe
sorting should not change)
● Create a series from given dataframe on “name” column and display top and last 10

# %%
# Get the index at which the minimum weight value is present
min_weight_index = df['Weight'].idxmin()
print("Index with minimum weight value:", min_weight_index)

# Sort values based on name in alphabetical order for the rows (original DataFrame sorting should not change)
df_sorted = df.sort_values(by='Name', ignore_index=True)
print(df_sorted)

# Create a series from the given dataframe on the "name" column and display top and last 10
name_series = df['Name']
print("Top 10 names:\n", name_series.head(10))
print("\nLast 10 names:\n", name_series.tail(10))
# Out:
# Index with minimum weight value: 152
#                 Name                    Team  Number Position  Age  Weight  \
# 0       Aaron Brooks           Chicago Bulls       0       PG   31     161
# 1       Aaron Gordon           Orlando Magic       0       PF   20     220
# 2     Aaron Harrison       Charlotte Hornets       9       SG   21     210
# 3      Adreian Payne  Minnesota Timberwolves      33       PF   25     237
# 4         Al Horford           Atlanta Hawks      15        C   30     245
# ..               ...                     ...     ...      ...  ...     ...
# 452  Wilson Chandler          Denver Nuggets      21       SF   29     225
# 453   Xavier Munford       Memphis Grizzlies      14       PG   24     180
# 454      Zach LaVine  Minnesota Timberwolves       8       PG   21     189
# 455    Zach Randolph       Memphis Grizzlies      50       PF   34     260
# 456    Zaza Pachulia        Dallas Mavericks      27        C   32     275
#
#             College      Salary
# 0            Oregon   2250000.0
# 1           Arizona   4171680.0
# 2          Kentucky    525093.0
# 3    Michigan State   1938840.0
# 4           Florida  12000000.0
# ..              ...         ...
# 452          DePaul  10449438.0
# 453    Rhode Island         NaN
# 454            UCLA   2148360.0
# 455  Michigan State   9638555.0
# 456             NaN   5200000.0
#
# [457 rows x 8 columns]
# Top 10 names:
#  0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object
#
# Last 10 names:
#  447       Rudy Gobert
# 448    Gordon Hayward
# 449       Rodney Hood
# 450        Joe Ingles
# 451     Chris Johnson
# 452        Trey Lyles
# 453      Shelvin Mack
# 454         Raul Neto
# 455      Tibor Pleiss
# 456       Jeff Withey
# Name: Name, dtype: object
